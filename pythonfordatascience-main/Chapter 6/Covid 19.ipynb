# %%
import pandas as pd

covid = pd.read_csv("covid_19.csv")

covid
# Out:
#               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
covid.info
# Out:
# <bound method DataFrame.info of               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
covid[covid["population"].isna()]
# Out:
#               country      continent  population         day  \
# 3    Diamond-Princess            NaN         NaN  2024-06-30
# 6          MS-Zaandam            NaN         NaN  2024-06-30
# 212     North-America  North-America         NaN  2024-06-30
# 213              Asia           Asia         NaN  2024-06-30
# 214            Europe         Europe         NaN  2024-06-30
# 215     South-America  South-America         NaN  2024-06-30
# 216           Oceania        Oceania         NaN  2024-06-30
# 217            Africa         Africa         NaN  2024-06-30
# 218               All            All         NaN  2024-06-30
#
#                           time      Cases    Recovered     Deaths  Tests
# 3    2024-06-30T16:15:16+00:00        712        699.0       13.0    NaN
# 6    2024-06-30T16:15:16+00:00          9          7.0        2.0    NaN
# 212  2024-06-30T16:15:10+00:00  131889132  127665129.0  1695941.0    NaN
# ...

# %%
covid.Cases.mean()
# Out:
# 8883449.365546219

# %%
covid.Cases.min()
# Out:
# 9

# %%
covid.Cases.max()
# Out:
# 704753890

# %%
covid.Cases.describe()
# Out:
# count    2.380000e+02
# mean     8.883449e+06
# std      5.193031e+07
# min      9.000000e+00
# 25%      2.741875e+04
# 50%      2.320425e+05
# 75%      1.565481e+06
# max      7.047539e+08
# Name: Cases, dtype: float64

# %%
covid.describe()
# Out:
#          population         Cases     Recovered        Deaths         Tests
# count  2.290000e+02  2.380000e+02  1.900000e+02  2.330000e+02  2.130000e+02
# mean   3.469404e+07  8.883449e+06  1.006214e+07  9.026621e+04  3.298829e+07
# std    1.386374e+08  5.193031e+07  5.555519e+07  5.163434e+05  1.198779e+08
# min    7.990000e+02  9.000000e+00  2.000000e+00  1.000000e+00  7.850000e+03
# 25%    4.454310e+05  2.741875e+04  2.197250e+04  2.250000e+02  3.478150e+05
# 50%    5.797805e+06  2.320425e+05  2.351455e+05  2.570000e+03  2.226216e+06
# 75%    2.210284e+07  1.565481e+06  2.078212e+06  1.805700e+04  1.346373e+07
# max    1.448471e+09  7.047539e+08  6.756198e+08  7.010681e+06  1.186852e+09

# %%
import pandas as pd

# Assuming covid is a pandas DataFrame already
grp_continent = covid.groupby("continent")

covid_list = []  # Rename this from 'covid' to 'covid_list'

for grp, grp_info in grp_continent:
    covid_dict = {}
    
    # print(grp)
    covid_dict["Country"] = grp_info.country.count()
    covid_dict["Population"] = grp_info.population.sum()
    covid_dict["Cases"] = grp_info.Cases.sum()
    covid_dict["Recovered"] = grp_info.Recovered.sum()
    covid_dict["Deaths"] = grp_info.Deaths.sum()
    covid_dict["Tests"] = grp_info.Tests.sum()
    
    covid_list.append(covid_dict)

covid_df = pd.DataFrame(covid_list)
covid_df
# Out:
#    Country    Population      Cases    Recovered     Deaths         Tests
# 0       59  1.406729e+09   25721848   21302322.0   517784.0  1.110326e+08
# 1        1  0.000000e+00  704753890  675619811.0  7010681.0  0.000000e+00
# 2       51  4.711357e+09  443000530  314197120.0  3107324.0  2.404652e+09
# 3       49  7.475438e+08  506812396  484551278.0  4203648.0  2.848047e+09
# 4       40  5.981409e+08  263778264  254148368.0  3391882.0  1.325710e+09
# 5       21  4.347041e+07   29791542   29367897.0    66030.0  9.166819e+07
# 6       15  4.376944e+08  140401758  132619080.0  2734664.0  2.453954e+08

# %%
covid_df = covid_df.reset_index(drop=True)
covid_df
# Out:
#    Country    Population      Cases    Recovered     Deaths         Tests
# 0       59  1.406729e+09   25721848   21302322.0   517784.0  1.110326e+08
# 1        1  0.000000e+00  704753890  675619811.0  7010681.0  0.000000e+00
# 2       51  4.711357e+09  443000530  314197120.0  3107324.0  2.404652e+09
# 3       49  7.475438e+08  506812396  484551278.0  4203648.0  2.848047e+09
# 4       40  5.981409e+08  263778264  254148368.0  3391882.0  1.325710e+09
# 5       21  4.347041e+07   29791542   29367897.0    66030.0  9.166819e+07
# 6       15  4.376944e+08  140401758  132619080.0  2734664.0  2.453954e+08

# %%
covid_df.corr(numeric_only=True)
# Out:
#              Country  Population     Cases  Recovered    Deaths     Tests
# Country     1.000000    0.579104 -0.249127  -0.318690 -0.427826  0.581116
# Population  0.579104    1.000000  0.126313  -0.035997 -0.092664  0.550703
# Cases      -0.249127    0.126313  1.000000   0.985973  0.937068  0.415506
# Recovered  -0.318690   -0.035997  0.985973   1.000000  0.959235  0.338477
# Deaths     -0.427826   -0.092664  0.937068   0.959235  1.000000  0.212069
# Tests       0.581116    0.550703  0.415506   0.338477  0.212069  1.000000

# %%
# There is a correlation of 0.483042 between Population and Cases. There is a positive relationship between Population and Cases, whereby the higher the number of Population, the higher the number of Cases
# There is a significant positive correlation between Cases and Tests of 0.987. In which, the higher the number of tests administered, the higher the number of cases discovered
